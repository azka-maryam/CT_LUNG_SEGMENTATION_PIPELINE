# %%
import SimpleITK as sitk
import pandas as pd
import numpy as np
import os

# Input (preprocessed) and output (csv_results) folders
input_folder = r"C:\Users\R c\Documents\CT_pipeline_Portfolio\preprocessed"
output_folder = r"C:\Users\R c\Documents\CT_pipeline_Portfolio\csv_results"
os.makedirs(output_folder, exist_ok=True)

summary = []

for file in os.listdir(input_folder):
    if file.endswith(".nii.gz"):
        path = os.path.join(input_folder, file)
        img = sitk.ReadImage(path)
        arr = sitk.GetArrayFromImage(img)

        stats = {
            "filename": file,
            "size_x": img.GetSize()[0],
            "size_y": img.GetSize()[1],
            "size_z": img.GetSize()[2],
            "spacing_x": img.GetSpacing()[0],
            "spacing_y": img.GetSpacing()[1],
            "spacing_z": img.GetSpacing()[2],
            "origin_x": img.GetOrigin()[0],
            "origin_y": img.GetOrigin()[1],
            "origin_z": img.GetOrigin()[2],
            "mean_intensity": float(np.mean(arr)),
            "min_intensity": float(np.min(arr)),
            "max_intensity": float(np.max(arr))
        }

        summary.append(stats)

df = pd.DataFrame(summary)
output_path = os.path.join(output_folder, "preprocessed_data_stats.csv")
df.to_csv(output_path, index=False)

print("✅ Stats saved to:", output_path)
print(df)
# Out:
# ✅ Stats saved to: C:\Users\R c\Documents\CT_pipeline_Portfolio\csv_results\preprocessed_data_stats.csv
#             filename  size_x  size_y  size_z  spacing_x  spacing_y  spacing_z  \
# 0  01_patient.nii.gz     390     390     348        1.0        1.0        1.0
# 1  02_patient.nii.gz     390     390     348        1.0        1.0        1.0
# 2  03_patient.nii.gz     390     390     348        1.0        1.0        1.0
# 3  04_patient.nii.gz     390     390     348        1.0        1.0        1.0
# 4  05_patient.nii.gz     390     390     348        1.0        1.0        1.0
#
#    origin_x    origin_y  origin_z  mean_intensity  min_intensity  \
# 0    -195.0 -171.699997   -347.75        0.257314            0.0
# 1    -195.0 -171.699997   -347.75        0.257314            0.0
# 2    -195.0 -171.699997   -347.75        0.257314            0.0
# 3    -195.0 -171.699997   -347.75        0.257314            0.0
# 4    -195.0 -171.699997   -347.75        0.257314            0.0
#
#    max_intensity
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
